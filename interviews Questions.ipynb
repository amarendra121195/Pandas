# %%
st1=['sdfgh','jhgf','erty','uytre']
st1[::-2]
# Out:
# ['uytre', 'jhgf']

# %%
from collections import Counter

# %%
str2='Amarendra Kumar Kushwaha'
str2=str2.casefold()
''.join(reversed(str2))
# Out:
# 'ahawhsuk ramuk ardnerama'

# %%
vowels='aeiouAEIOU'
vowels_list=filter(lambda x: x in vowels,str2)
count_vowels=dict(Counter(vowels_list))
count_vowels
# Out:
# {'a': 6, 'e': 1, 'u': 2}

# %%
vowels='aeiouAEIOU'
vowels_list=filter(lambda x: x not in vowels,str2)
count_consonet=dict(Counter(vowels_list))
count_consonet
# Out:
# {'m': 2, 'r': 3, 'n': 1, 'd': 1, ' ': 2, 'k': 2, 's': 1, 'h': 2, 'w': 1}

# %%
from collections import Counter
str1='Amarendra kumar kushwaha and also amaredra kumar kushwaha'
dct=dict(Counter(filter(lambda x : x ,str1.split())))
print(dct)
# Out:
# {'Amarendra': 1, 'kumar': 2, 'kushwaha': 2, 'and': 1, 'also': 1, 'amaredra': 1}

# %%
dct={}
for i in str2:
    if i in vowels:
        if i in dct:
            dct[i]+=1
        else:
            dct[i]=1
print(dct)
# Out:
# {'a': 6, 'e': 1, 'u': 2}

# %%
dct1={}
dct={}
for i in str2:
    if i not in vowels:
        if i in dct1:
            dct1[i]+=1
        else:
            dct1[i]=1
    else:
        if i in dct:
            dct[i]+=1
        else:
            dct[i]=1
print(dct1)
print(dct)
# Out:
# {'m': 2, 'r': 3, 'n': 1, 'd': 1, ' ': 2, 'k': 2, 's': 1, 'h': 2, 'w': 1}
# {'a': 6, 'e': 1, 'u': 2}

# %%
max_consonent=max(count_consonet.values())
[num for num,count in count_consonet.items() if max_consonent==count]
# Out:
# ['r']

# %%
for i in str2[::-1]:
    print(i,end='')
# Out:
# ahawhsuk ramuk ardnerama

# %%
import array
from array import*

# %%
n=int(input('enter the numbers : '))
output=set()
for i in range(n):
    
    output.add(int(input('enter the array values :')))
    
print(output)
# Out:
# enter the numbers : 1
# enter the array values :4
# {4}

# %%
l=[{1:[(('ram','shayam','sita'),2)]},
   {2:[(('shyam','shyam','sita'),5)]},
   {3:[(('gita','gita','sita'),1)]}]

# %%
dic={'ram':1,'red':2,'we':2,'tw':1,'ty':1}

# %%
sorted(dic.items(),key=lambda x: (-x[1],x[0]))
# Out:
# [('red', 2), ('we', 2), ('ram', 1), ('tw', 1), ('ty', 1)]

# %%
tb=dic.items()
tb
# Out:
# dict_items([('ram', 1), ('red', 2), ('we', 2), ('tw', 1), ('ty', 1)])

# %%
l[1]
# Out:
# {2: [(('shyam', 'shyam', 'sita'), 5)]}

# %%
l
# Out:
# [{1: [(('ram', 'shayam', 'sita'), 2)]},
#  {2: [(('shyam', 'shyam', 'sita'), 5)]},
#  {3: [(('gita', 'gita', 'sita'), 1)]}]

# %%
key_list=[]
for ls in l:
    for k,v in ls.items():
#         print(k,v)
        for i in range(len(v)):
            if v[0][0][0]==v[0][0][1]:
                key_list.append(k)

# %%
key_list
# Out:
# [2, 3]

# %%
l1=[
   [(('ram','shayam','sita'),2)],
   [(('shyam','ramu','sita'),5)],
   [(('gita','sabita','sita'),1)],
   [(('ram','shayam','sita'),9)],
   [(('shyam','ramu','sita'),3)],
   [(('gita','sabita','sita'),7)]
]

# %%
for i in l1:
    print(i)
# Out:
# [(('ram', 'shayam', 'sita'), 2)]
# [(('shyam', 'ramu', 'sita'), 5)]
# [(('gita', 'sabita', 'sita'), 1)]
# [(('ram', 'shayam', 'sita'), 9)]
# [(('shyam', 'ramu', 'sita'), 3)]
# [(('gita', 'sabita', 'sita'), 7)]

# %%
counts={}
for ls in l1:
    for key,count in ls:
        if key in counts:
            counts[key]+=count
        else:
            counts[key]=count
print(counts)
# Out:
# {('ram', 'shayam', 'sita'): 11, ('shyam', 'ramu', 'sita'): 8, ('gita', 'sabita', 'sita'): 8}

# %%
counts
# Out:
# {('ram', 'shayam', 'sita'): 11,
#  ('shyam', 'ramu', 'sita'): 8,
#  ('gita', 'sabita', 'sita'): 8}

# %%
l=[[(('ram','shayam','sita'),11)],
   [(('shyam','ramu','sita'),8)],
   [(('gita','sabita','sita'),8)]]

# %%
l=['a','c','b','c','d','a','c','a','d','a','c']

# %%
from collections import Counter
Counter(l)
# Out:
# Counter({'a': 4, 'c': 4, 'b': 1, 'd': 2})

# %%
Counter(l).most_common()
# Out:
# [('a', 4), ('c', 4), ('d', 2), ('b', 1)]

# %%
set(l)
# Out:
# {'a', 'b', 'c', 'd'}

# %%
l
# Out:
# ['a', 'c', 'b', 'c', 'd', 'a', 'c', 'a', 'd', 'a', 'c']

# %%
l.pop()
# Out:
# 'c'

# %%
l
# Out:
# ['a', 'c', 'b', 'c', 'd', 'a', 'c', 'a', 'd', 'a']

# %%
l.index('d')
# Out:
# 4

# %%
l.count('a')
# Out:
# 4

# %%
sorted(l)
# Out:
# ['a', 'a', 'a', 'a', 'b', 'c', 'c', 'c', 'd', 'd']

# %%
a=[[1,2,3,4,5],[5,6,7,8,9,4]]

# %%
for i in range(len(a)):
    for j in range(len(a[i])):
        print(i,j,a[i][j])
    print()
# Out:
# 0 0 1
# 0 1 2
# 0 2 3
# 0 3 4
# 0 4 5
#
# 1 0 5
# 1 1 6
# 1 2 7
# 1 3 8
# 1 4 9
# 1 5 4

# %%
a=[[1,2,3,4],[3,4,5,6],[5,6,7]]

# %%
output=[]
for i in range(len(a)):
    for j in range(len(a[i])):
        output.append(i,j,a[i][j])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15500\1837023336.py in <module>
#       2 for i in range(len(a)):
#       3     for j in range(len(a[i])):
# ----> 4         output.append(i,j,a[i][j])
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
# very very important questions
from functools import reduce
output=reduce(lambda x,z:x+z,a,[])
output
# Out:
# [1, 2, 3, 4, 3, 4, 5, 6, 5, 6, 7]

# %%
for r in a:
    for j in r:
        print(j)
# Out:
# 1
# 2
# 3
# 4
# 3
# 4
# 5
# 6
# 5
# 6
# 7

# %%
from functools import reduce

# %%
re=list(reduce(lambda x,y:x+y,a))
re
# Out:
# [1, 2, 3, 4, 3, 4, 5, 6, 5, 6, 7]

# %%
redu=reduce(lambda x,y:x+y,re)
redu
# Out:
# 46

# %%
l[1]='d'
l
# Out:
# ['a', 'd', 'b', 'c', 'd', 'a', 'c', 'a', 'd', 'a']

# %%
for i in l:
    if i=='d':
        print(l.index(i))
# Out:
# 1
# 1
# 1

# %%
print('my name is amarendra kumar'+' '+'from bihar'+' '+"and i leave in 'Pune'")
# Out:
# my name is amarendra kumar from bihar and i leave in 'Pune'

# %%
# # Write a program in Python to execute the Bubble sort algorithm.
# #a=[32,5,3,6,7,54,87]
# def bubble_sort(a):
#     b=len(a)
#     for x in range(b):
#         for y in range(b-x):
#             a[y]=a[y+1]
    
# a=[32,5,3,6,7,54,87]
# bubble_sort(a)

# %%
import numpy as np
arr = np.array([1, 3, 2, 4, 5])
print(arr.argsort()[-3:][::-1])
# Out:
# [4 3 1]

# %%
def pyfunc(r):
    for x in range(r):
        print(' '*(r-x-1)+'*'*(2*x+1))    
pyfunc(5)
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
for i in range(5):
    print('*'*i)
# Out:
# *
# **
# ***
# ****

# %%
import numpy as np

# %%
np.array([3]*4, dtype="int32")
# Out:
# array([3, 3, 3, 3])

# %%
import pandas as pd
import numpy as np

# %%
str1='amrendra kumar kushwaha'

# %%
''.join(reversed(str1))
# Out:
# 'ahawhsuk ramuk ardnerma'

# %%
for i in str1[::-1]:
    print(i,end='')
# Out:
# ahawhsuk ramuk ardnerma

# %%
data=pd.date_range('4/4/2023',periods=7)
data
# Out:
# DatetimeIndex(['2023-04-04', '2023-04-05', '2023-04-06', '2023-04-07',
#                '2023-04-08', '2023-04-09', '2023-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6,4)
# Out:
# array([[ 1.14004757, -0.70514872, -0.87183048, -0.3984931 ],
#        [-0.67567891, -1.38396076, -0.10895757, -0.75798539],
#        [-0.09252764,  1.56339855, -1.24835912, -0.54595209],
#        [ 0.91046228, -0.01878768,  0.90160992,  0.37066623],
#        [ 1.71339023,  0.40638299,  0.40921138,  1.1342373 ],
#        [-0.06326817, -1.01280357, -0.07344242, -0.21500941]])

# %%
df=pd.DataFrame(np.random.randn(7,4),index=data,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222

# %%
df2=pd.DataFrame({
    'A':1.0,
    "B":pd.Timestamp('20230409'),
    'C':pd.Series(1,index=list(range(4)),dtype='float64'),
    'D':np.array([3]*4,dtype='float32'),
    'E':pd.Categorical(['test','train','test','train']),
    'F':'foo'
})
    
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2023-04-09  1.0  3.0   test  foo
# 1  1.0 2023-04-09  1.0  3.0  train  foo
# 2  1.0 2023-04-09  1.0  3.0   test  foo
# 3  1.0 2023-04-09  1.0  3.0  train  foo

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
df2.append(['sdfgh','jhgf','erty','uytre'],ignore_index=False,verify_integrity=False, sort=None)
# Out:
# C:\Users\Amarendra Kumar\AppData\Local\Temp\ipykernel_15500\3345535758.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2.append(['sdfgh','jhgf','erty','uytre'],ignore_index=False,verify_integrity=False, sort=None)
# C:\Users\Amarendra Kumar\AppData\Local\Temp\ipykernel_15500\3345535758.py:1: FutureWarning: Passing non boolean values for sort is deprecated and will error in a future version!
#   df2.append(['sdfgh','jhgf','erty','uytre'],ignore_index=False,verify_integrity=False, sort=None)
#      A          B    C    D      E    F      0
# 0  1.0 2023-04-09  1.0  3.0   test  foo    NaN
# 1  1.0 2023-04-09  1.0  3.0  train  foo    NaN
# 2  1.0 2023-04-09  1.0  3.0   test  foo    NaN
# 3  1.0 2023-04-09  1.0  3.0  train  foo    NaN
# 0  NaN        NaT  NaN  NaN    NaN  NaN  sdfgh
# 1  NaN        NaT  NaN  NaN    NaN  NaN   jhgf
# 2  NaN        NaT  NaN  NaN    NaN  NaN   erty
# ...

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-04-09 00:00:00'), 1.0, 3.0, 'test', 'foo'],
#        [1.0, Timestamp('2023-04-09 00:00:00'), 1.0, 3.0, 'train', 'foo'],
#        [1.0, Timestamp('2023-04-09 00:00:00'), 1.0, 3.0, 'test', 'foo'],
#        [1.0, Timestamp('2023-04-09 00:00:00'), 1.0, 3.0, 'train', 'foo']],
#       dtype=object)

# %%
df['E']=df['B'].values.tolist()

# %%
df
# Out:
#                    A         B         C         D         E
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948  0.238664
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536  0.824943
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461  0.270958
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190  1.506649
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802 -1.677109
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546  0.568110
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222  0.683912

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    E         D         C         B         A
# 2023-04-04  0.238664  0.158948  0.721700  0.238664 -0.167994
# 2023-04-05  0.824943  0.649536 -0.714558  0.824943  2.076234
# 2023-04-06  0.270958  0.560461  1.453090  0.270958 -0.615754
# 2023-04-07  1.506649  0.166190 -0.002718  1.506649  1.153603
# 2023-04-08 -1.677109 -0.823802  1.192388 -1.677109 -1.871885
# 2023-04-09  0.568110 -0.830546 -1.434301  0.568110  0.924821
# 2023-04-10  0.683912 -0.028222  0.348320  0.683912  1.820574

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D         E
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802 -1.677109
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948  0.238664
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461  0.270958
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546  0.568110
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222  0.683912
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536  0.824943
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190  1.506649

# %%
df
# Out:
#                    A         B         C         D         E
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948  0.238664
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536  0.824943
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461  0.270958
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190  1.506649
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802 -1.677109
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546  0.568110
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222  0.683912

# %%
df["A"]
# Out:
# 2023-04-04   -0.167994
# 2023-04-05    2.076234
# 2023-04-06   -0.615754
# 2023-04-07    1.153603
# 2023-04-08   -1.871885
# 2023-04-09    0.924821
# 2023-04-10    1.820574
# Freq: D, Name: A, dtype: float64

# %%
df.loc[:,'E']
# Out:
# 2023-04-04    0.238664
# 2023-04-05    0.824943
# 2023-04-06    0.270958
# 2023-04-07    1.506649
# 2023-04-08   -1.677109
# 2023-04-09    0.568110
# 2023-04-10    0.683912
# Freq: D, Name: E, dtype: float64

# %%
y=df.iloc[:,-1:]
y
# Out:
#                    E
# 2023-04-04  0.238664
# 2023-04-05  0.824943
# 2023-04-06  0.270958
# 2023-04-07  1.506649
# 2023-04-08 -1.677109
# 2023-04-09  0.568110
# 2023-04-10  0.683912

# %%
x=df.iloc[:,:-1]
x
# Out:
#                    A         B         C         D
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222

# %%
len(df)
# Out:
# 7

# %%
df['F']=np.array([5]*len(df),dtype='float32')

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948  0.238664  5.0
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536  0.824943  5.0
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461  0.270958  5.0
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190  1.506649  5.0
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802 -1.677109  5.0
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546  0.568110  5.0
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222  0.683912  5.0

# %%
pd.Categorical(['test','train','test','train'])
# Out:
# ['test', 'train', 'test', 'train']
# Categories (2, object): ['test', 'train']

# %%
pd.Series(1,index=list(range(4)),dtype='float64')
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# dtype: float64

# %%
np.array([3]*4,dtype='float32')
# Out:
# array([3., 3., 3., 3.], dtype=float32)

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.167994  0.238664  0.721700  0.158948  0.238664  5.0
# 2023-04-05  2.076234  0.824943 -0.714558  0.649536  0.824943  5.0
# 2023-04-06 -0.615754  0.270958  1.453090  0.560461  0.270958  5.0
# 2023-04-07  1.153603  1.506649 -0.002718  0.166190  1.506649  5.0
# 2023-04-08 -1.871885 -1.677109  1.192388 -0.823802 -1.677109  5.0
# 2023-04-09  0.924821  0.568110 -1.434301 -0.830546  0.568110  5.0
# 2023-04-10  1.820574  0.683912  0.348320 -0.028222  0.683912  5.0

# %%
df[df>0]=-df

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0
# 2023-04-08 -1.871885 -1.677109 -1.192388 -0.823802 -1.677109 -5.0
# 2023-04-09 -0.924821 -0.568110 -1.434301 -0.830546 -0.568110 -5.0
# 2023-04-10 -1.820574 -0.683912 -0.348320 -0.028222 -0.683912 -5.0

# %%
df1=df.reindex(index=data[0:4],columns=list(df.columns)+['G'])

# %%
df1
# Out:
#                    A         B         C         D         E    F   G
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0 NaN
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0 NaN
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0 NaN
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0 NaN

# %%
df1['G'].fillna(df['E'].mean(),inplace=True)

# %%
df1
# Out:
#                    A         B         C         D         E    F         G
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0 -0.824335
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0 -0.824335
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0 -0.824335
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0 -0.824335

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0
# 2023-04-08 -1.871885 -1.677109 -1.192388 -0.823802 -1.677109 -5.0
# 2023-04-09 -0.924821 -0.568110 -1.434301 -0.830546 -0.568110 -5.0
# 2023-04-10 -1.820574 -0.683912 -0.348320 -0.028222 -0.683912 -5.0

# %%
df1
# Out:
#                    A         B         C         D         E    F         G
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0 -0.824335
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0 -0.824335
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0 -0.824335
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0 -0.824335

# %%
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2023-04-09  1.0  3.0   test  foo
# 1  1.0 2023-04-09  1.0  3.0  train  foo
# 2  1.0 2023-04-09  1.0  3.0   test  foo
# 3  1.0 2023-04-09  1.0  3.0  train  foo

# %%
l=[1,2,3,4,5]
product=1
for i in l:
    product*=i
print(product)
# Out:
# 120

# %%
from functools import reduce
reduce(lambda x,y:x*y,l)
# Out:
# 120

# %%
df1['F']='foo'
df1
# Out:
#                    A         B         C         D         E    F         G
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2023-04-09  1.0  3.0   test  foo
# 1  1.0 2023-04-09  1.0  3.0  train  foo
# 2  1.0 2023-04-09  1.0  3.0   test  foo
# 3  1.0 2023-04-09  1.0  3.0  train  foo

# %%
pd.merge(df1,df2,on='F')
# Out:
#          A_x       B_x       C_x       D_x       E_x    F         G  A_y  \
# 0  -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335  1.0
# 1  -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335  1.0
# 2  -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335  1.0
# 3  -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335  1.0
# 4  -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335  1.0
# 5  -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335  1.0
# 6  -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335  1.0
# 7  -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335  1.0
# 8  -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335  1.0
# 9  -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335  1.0
# 10 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335  1.0
# 11 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335  1.0
# ...

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664 -5.0
# 2023-04-05 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943 -5.0
# 2023-04-06 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958 -5.0
# 2023-04-07 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649 -5.0
# 2023-04-08 -1.871885 -1.677109 -1.192388 -0.823802 -1.677109 -5.0
# 2023-04-09 -0.924821 -0.568110 -1.434301 -0.830546 -0.568110 -5.0
# 2023-04-10 -1.820574 -0.683912 -0.348320 -0.028222 -0.683912 -5.0

# %%
# dict to tuple multi index
df3=pd.DataFrame({
    ('a','b'):{('A','B'):1,('A','B'):2},
    ('b','b'):{('B','B'):2,('A''C'):2},
    ('a','c'):{('A','C'):5,('A','D'):2},
    ('a','d'):{('D','B'):7,('D','A'):2},
})

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d
# (A, B)  2.0  NaN  NaN  NaN
# (B, B)  NaN  2.0  NaN  NaN
# AC      NaN  2.0  NaN  NaN
# (A, C)  NaN  NaN  5.0  NaN
# (A, D)  NaN  NaN  2.0  NaN
# (D, B)  NaN  NaN  NaN  7.0
# (D, A)  NaN  NaN  NaN  2.0

# %%
df3.fillna(df3['a','c'].mean(),inplace=True)

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d
# (A, B)  2.0  3.5  3.5  3.5
# (B, B)  3.5  2.0  3.5  3.5
# AC      3.5  2.0  3.5  3.5
# (A, C)  3.5  3.5  5.0  3.5
# (A, D)  3.5  3.5  2.0  3.5
# (D, B)  3.5  3.5  3.5  7.0
# (D, A)  3.5  3.5  3.5  2.0

# %%
df3['a','e']=df3['a','d'][:-4]

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d    e
# (A, B)  2.0  3.5  3.5  3.5  3.5
# (B, B)  3.5  2.0  3.5  3.5  3.5
# AC      3.5  2.0  3.5  3.5  3.5
# (A, C)  3.5  3.5  5.0  3.5  NaN
# (A, D)  3.5  3.5  2.0  3.5  NaN
# (D, B)  3.5  3.5  3.5  7.0  NaN
# (D, A)  3.5  3.5  3.5  2.0  NaN

# %%
df3['a','e'].fillna(df3['a','e'].mean(),inplace=True)

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d    e
# (A, B)  2.0  3.5  3.5  3.5  3.5
# (B, B)  3.5  2.0  3.5  3.5  3.5
# AC      3.5  2.0  3.5  3.5  3.5
# (A, C)  3.5  3.5  5.0  3.5  3.5
# (A, D)  3.5  3.5  2.0  3.5  3.5
# (D, B)  3.5  3.5  3.5  7.0  3.5
# (D, A)  3.5  3.5  3.5  2.0  3.5

# %%
df1
# Out:
#           A         B         C         D         E    F         G
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
df1.assign(score_ratio=df1['A']/df1['C'])
# Out:
#           A         B         C         D         E    F         G  \
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335
#
#    score_ratio
# 0     0.232776
# 1     2.905619
# 2     0.423755
# 3   424.441199

# %%
df1
# Out:
#           A         B         C         D         E    F         G
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
y=df1.iloc[:,-1:]
y
# Out:
#           G
# 0 -0.824335
# 1 -0.824335
# 2 -0.824335
# 3 -0.824335

# %%
x=df1.iloc[:,:-1]

# %%
x
# Out:
#           A         B         C         D         E    F
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d    e
# (A, B)  2.0  3.5  3.5  3.5  3.5
# (B, B)  3.5  2.0  3.5  3.5  3.5
# AC      3.5  2.0  3.5  3.5  3.5
# (A, C)  3.5  3.5  5.0  3.5  3.5
# (A, D)  3.5  3.5  2.0  3.5  3.5
# (D, B)  3.5  3.5  3.5  7.0  3.5
# (D, A)  3.5  3.5  3.5  2.0  3.5

# %%
df1.assign(score_ratio=lambda x: (x['A']/x['C']))
# Out:
#           A         B         C         D         E    F         G  \
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335
#
#    score_ratio
# 0     0.232776
# 1     2.905619
# 2     0.423755
# 3   424.441199

# %%
df1
# Out:
#           A         B         C         D         E    F         G
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
np.exp(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'exp'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15500\3574329877.py in <module>
# ----> 1 np.exp(df1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2099         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2100     ):
# -> 2101         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2102
#    2103     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
# ...

# %%
df1
# Out:
#           A         B         C         D         E    F         G
# 0 -0.167994 -0.238664 -0.721700 -0.158948 -0.238664  foo -0.824335
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2 -0.615754 -0.270958 -1.453090 -0.560461 -0.270958  foo -0.824335
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
df1.columns=[x.lower() for x in df1.columns]
df1.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g'], dtype='object')

# %%
for i in df1.iterrows():
    print(i)
# Out:
# (0, a   -0.167994
# b   -0.238664
# c     -0.7217
# d   -0.158948
# e   -0.238664
# f         foo
# g   -0.824335
# Name: 0, dtype: object)
# (1, a   -2.076234
# b   -0.824943
# c   -0.714558
# d   -0.649536
# e   -0.824943
# f         foo
# g   -0.824335
# Name: 1, dtype: object)
# (2, a   -0.615754
# b   -0.270958
# c    -1.45309
# d   -0.560461
# e   -0.270958
# f         foo
# g   -0.824335
# Name: 2, dtype: object)
# (3, a   -1.153603
# b   -1.506649
# c   -0.002718
# d    -0.16619
# e   -1.506649
# f         foo
# g   -0.824335
# Name: 3, dtype: object)

# %%
df1.iloc[::2]=np.nan
df1
# Out:
#           a         b         c         d         e    f         g
# 0       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 1 -2.076234 -0.824943 -0.714558 -0.649536 -0.824943  foo -0.824335
# 2       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 3 -1.153603 -1.506649 -0.002718 -0.166190 -1.506649  foo -0.824335

# %%
import pandas as pd
import numpy as np

# %%
df4=pd.read_csv('titanic.csv')

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df4.shape
# Out:
# (891, 12)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df4.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df4.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df4[::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mask=df4['Embarked']=='S'
df4[mask][0:10:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 3             4         1       1
# 6             7         0       1
# 8             9         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 0       0  A/5 21171   7.2500   NaN        S
# 3       0     113803  53.1000  C123        S
# 6       0      17463  51.8625   E46        S
# 8       2     347742  11.1333   NaN        S
# 11      0     113783  26.5500  C103        S

# %%
df4['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
str1='amarenra kumar kushwaha'
str1.split()[1]
# Out:
# 'kumar'

# %%
# df4['Titel']=df4['Name'].str.split(',').str.get(0)
df4['Titel']=df4['Name'].apply(lambda x:x.split()[0])
df4['Surname']=df4['Name'].apply(lambda x:x.split()[1])
df4['new_name']=df4['Name'].apply(lambda x:x.split()[2])
# df4['new_long_name']=df4['Name'].apply(lambda x : x.split()[3])

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       Titel Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund,     Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings,    Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen,   Miss.
# ...

# %%
df4.isnull().sum()/100
# Out:
# PassengerId    0.00
# Survived       0.00
# Pclass         0.00
# Name           0.00
# Sex            0.00
# Age            1.77
# SibSp          0.00
# Parch          0.00
# Ticket         0.00
# Fare           0.00
# Cabin          6.87
# Embarked       0.02
# Titel          0.00
# Surname        0.00
# new_name       0.00
# dtype: float64

# %%
df4.shape
# Out:
# (891, 15)

# %%
df4=df4[df4['Embarked'].notnull()]

# %%
# df4.dropna(axis=0,inplace=True)

# %%
df4.shape
# Out:
# (889, 15)

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0

# %%
df.apply(lambda x: x.max()-x.min())
# Out:
# A    1.467544
# B    1.351079
# C    1.930684
# D    2.356566
# E    1.351079
# F    0.000000
# dtype: float64

# %%
df4['Age'].fillna(df4['Age'].mean(),inplace=True)

# %%
df4.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Titel            0
# Surname          0
# new_name         0
# dtype: int64

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked       Titel Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund,     Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings,    Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen,   Miss.
# ...

# %%
# df4['Cabin'].fillna(df4['Cabin']=='bfill')

# %%
df4['Cabin'].fillna(df4['Cabin'].mode().iloc[0],inplace=True)

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked       Titel Surname  \
# 0      0         A/5 21171   7.2500  B96 B98        S     Braund,     Mr.
# 1      0          PC 17599  71.2833      C85        C    Cumings,    Mrs.
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S  Heikkinen,   Miss.
# ...

# %%
df4.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Titel          0
# Surname        0
# new_name       0
# dtype: int64

# %%
df4.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0

# %%
df.transform([np.abs,lambda x:x+1])
# Out:
#                    A                   B                   C            \
#             absolute  <lambda>  absolute  <lambda>  absolute  <lambda>
# 2023-04-04  0.197208  0.802792  0.003765  0.996235  1.741248 -0.741248
# 2023-04-05  1.516528 -0.516528  0.332065  0.667935  0.073774  0.926226
# 2023-04-06  0.677221  0.322779  0.064061  0.935939  1.199236 -0.199236
# 2023-04-07  1.445407 -0.445407  1.354844 -0.354844  1.601813 -0.601813
# 2023-04-08  1.664752 -0.664752  0.387528  0.612472  0.547983  0.452017
# 2023-04-09  0.479883  0.520117  0.756036  0.243964  2.004458 -1.004458
# 2023-04-10  1.133044 -0.133044  0.325432  0.674568  0.649765  0.350235
#
#                    D                   E                  F
#             absolute  <lambda>  absolute  <lambda> absolute <lambda>
# 2023-04-04  0.770013  0.229987  0.003765  0.996235      5.0     -4.0
# 2023-04-05  0.713069  0.286931  0.332065  0.667935      5.0     -4.0
# ...

# %%
df
# Out:
#                    A         B         C         D         E    F
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0

# %%
s=pd.DataFrame(np.random.randn(5),index=list('abcde'))
s.T.transform([np.abs])
# Out:
#           a         b        c         d         e
#    absolute  absolute absolute  absolute  absolute
# 0  0.272984  1.476261  0.07759  0.818668  1.775629

# %%
s1=s[:4]
s1
# Out:
#           0
# a  0.272984
# b -1.476261
# c  0.077590
# d -0.818668

# %%
s2=s[1:]
s2
# Out:
#           0
# b -1.476261
# c  0.077590
# d -0.818668
# e -1.775629

# %%
s1.align(s2)
# Out:
# (          0
#  a  0.272984
#  b -1.476261
#  c  0.077590
#  d -0.818668
#  e       NaN,
#            0
#  a       NaN
#  b -1.476261
#  c  0.077590
#  d -0.818668
#  e -1.775629)

# %%
s1.align(s2,join='inner')
# Out:
# (          0
#  b -1.476261
#  c  0.077590
#  d -0.818668,
#            0
#  b -1.476261
#  c  0.077590
#  d -0.818668)

# %%
s1.align(s2,join='left')
# Out:
# (          0
#  a  0.272984
#  b -1.476261
#  c  0.077590
#  d -0.818668,
#            0
#  a       NaN
#  b -1.476261
#  c  0.077590
#  d -0.818668)

# %%
s.align(df,join='inner')
# Out:
# (Empty DataFrame
#  Columns: []
#  Index: [],
#  Empty DataFrame
#  Columns: []
#  Index: [])

# %%
s.align(df.iloc[0],axis=1)
# Out:
# (          0   A   B   C   D   E   F
#  a  0.272984 NaN NaN NaN NaN NaN NaN
#  b -1.476261 NaN NaN NaN NaN NaN NaN
#  c  0.077590 NaN NaN NaN NaN NaN NaN
#  d -0.818668 NaN NaN NaN NaN NaN NaN
#  e -1.775629 NaN NaN NaN NaN NaN NaN,
#  0         NaN
#  A   -0.197208
#  B   -0.003765
#  C   -1.741248
#  D   -0.770013
#  E   -0.003765
#  F   -5.000000
#  Name: 2023-04-04 00:00:00, dtype: float64)

# %%
df1.fillna(method='bfill')
# Out:
#           a         b         c         d         e    f         g
# 0 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065  foo -0.460533
# 1 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065  foo -0.460533
# 2 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844  foo -0.460533
# 3 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844  foo -0.460533

# %%
df1
# Out:
#           a         b         c         d         e    f         g
# 0       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 1 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065  foo -0.460533
# 2       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 3 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844  foo -0.460533

# %%
s.reindex(s.index.difference(['a','c']))
# Out:
#           0
# b -1.476261
# d -0.818668
# e -1.775629

# %%
s
# Out:
#           0
# a  0.272984
# b -1.476261
# c  0.077590
# d -0.818668
# e -1.775629

# %%
s.rename(str.upper)
# Out:
#           0
# A  0.272984
# B -1.476261
# C  0.077590
# D -0.818668
# E -1.775629

# %%
df.columns=[x.lower() for x in df.columns]

# %%
import pandas as pd
d=pd.DataFrame({
    "x":[1,2,3,4,5,6],"y":[10,20,30,40,50,60]},
    index=pd.MultiIndex.from_product([['a','b','c'],[1,2]])
)

# %%
d
# Out:
#      x   y
# a 1  1  10
#   2  2  20
# b 1  3  30
#   2  4  40
# c 1  5  50
#   2  6  60

# %%
d.rename_axis(index={"let":'abc'})
# Out:
#      x   y
# a 1  1  10
#   2  2  20
# b 1  3  30
#   2  4  40
# c 1  5  50
#   2  6  60

# %%
d.rename(columns={'y':'Y'},inplace=True)

# %%
d
# Out:
#      x   Y
# a 1  1  10
#   2  2  20
# b 1  3  30
#   2  4  40
# c 1  5  50
#   2  6  60

# %%
d.rename_axis(index={'let':'abc'},inplace=True)

# %%
d
# Out:
#      x   Y
# a 1  1  10
#   2  2  20
# b 1  3  30
#   2  4  40
# c 1  5  50
#   2  6  60

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                    a         b         c         d         e    f
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0

# %%
df.sort_values(by='b',ascending=False)
# Out:
#                    a         b         c         d         e    f
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0

# %%
df.nlargest(1,['a','c'])
# Out:
#                    a         b         c         d         e    f
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0

# %%
pd.Series(np.random.randn(8),dtype='float32')
# Out:
# 0   -0.049022
# 1   -1.091069
# 2   -1.646518
# 3   -0.283508
# 4   -0.487395
# 5    1.681158
# 6   -0.306722
# 7   -0.231082
# dtype: float32

# %%
pd.Series(np.random.randn(8))
# Out:
# 0    0.758748
# 1    0.020177
# 2   -0.307130
# 3   -0.409456
# 4    0.499125
# 5    1.320167
# 6    0.483037
# 7    0.384232
# dtype: float64

# %%
pd.Series(np.array(np.random.randn(8),dtype='float16'))
# Out:
# 0    0.881836
# 1   -1.210938
# 2    1.290039
# 3   -0.299805
# 4   -0.174683
# 5    0.266113
# 6   -0.998047
# 7    0.161743
# dtype: float16

# %%
a=pd.DataFrame({"A": pd.Series(np.random.randn(8),dtype='float32'),
                "B": pd.Series(np.random.randn(8)),
                "C": pd.Series(np.array(np.random.randn(8),dtype='float16'))})

# %%
a
# Out:
#           A         B         C
# 0  0.314322 -0.873796  0.851074
# 1 -1.274538 -0.345360 -0.857422
# 2 -0.985510 -1.411901  1.845703
# 3 -0.774135  0.639672 -2.224609
# 4  0.263699  0.784612  1.031250
# 5 -0.881478 -0.012516 -0.634277
# 6 -0.533661 -0.995825  0.455811
# 7  1.740885 -3.056281  1.573242

# %%
q=a.transform(abs)
q
# Out:
#           A         B         C
# 0  0.314322  0.873796  0.851074
# 1  1.274538  0.345360  0.857422
# 2  0.985510  1.411901  1.845703
# 3  0.774135  0.639672  2.224609
# 4  0.263699  0.784612  1.031250
# 5  0.881478  0.012516  0.634277
# 6  0.533661  0.995825  0.455811
# 7  1.740885  3.056281  1.573242

# %%
q.sort_values(by='A',ascending=False)
# Out:
#           A         B         C
# 7  1.740885  3.056281  1.573242
# 1  1.274538  0.345360  0.857422
# 2  0.985510  1.411901  1.845703
# 5  0.881478  0.012516  0.634277
# 3  0.774135  0.639672  2.224609
# 6  0.533661  0.995825  0.455811
# 0  0.314322  0.873796  0.851074
# 4  0.263699  0.784612  1.031250

# %%
df
# Out:
#                    a         b         c         d         e    f
# 2023-04-04 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
# 2023-04-05 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
# 2023-04-06 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
# 2023-04-07 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
# 2023-04-08 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
# 2023-04-09 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
# 2023-04-10 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0

# %%
df1
# Out:
#           a         b         c         d         e    f         g
# 0       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 1 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065  foo -0.460533
# 2       NaN       NaN       NaN       NaN       NaN  NaN       NaN
# 3 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844  foo -0.460533

# %%
df2
# Out:
#      A          B    C    D      E    F
# 0  1.0 2023-04-09  1.0  3.0   test  foo
# 1  1.0 2023-04-09  1.0  3.0  train  foo
# 2  1.0 2023-04-09  1.0  3.0   test  foo
# 3  1.0 2023-04-09  1.0  3.0  train  foo

# %%
df3
# Out:
#           a    b    a
#           b    b    c    d    e
# (A, B)  2.0  3.5  3.5  3.5  3.5
# (B, B)  3.5  2.0  3.5  3.5  3.5
# AC      3.5  2.0  3.5  3.5  3.5
# (A, C)  3.5  3.5  5.0  3.5  3.5
# (A, D)  3.5  3.5  2.0  3.5  3.5
# (D, B)  3.5  3.5  3.5  7.0  3.5
# (D, A)  3.5  3.5  3.5  2.0  3.5

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked       Titel Surname  \
# 0      0         A/5 21171   7.2500  B96 B98        S     Braund,     Mr.
# 1      0          PC 17599  71.2833      C85        C    Cumings,    Mrs.
# 2      0  STON/O2. 3101282   7.9250  B96 B98        S  Heikkinen,   Miss.
# ...

# %%
s
# Out:
#           0
# a  0.272984
# b -1.476261
# c  0.077590
# d -0.818668
# e -1.775629

# %%
d
# Out:
#      x   Y
# a 1  1  10
#   2  2  20
# b 1  3  30
#   2  4  40
# c 1  5  50
#   2  6  60

# %%
q
# Out:
#           A         B         C
# 0  0.314322  0.873796  0.851074
# 1  1.274538  0.345360  0.857422
# 2  0.985510  1.411901  1.845703
# 3  0.774135  0.639672  2.224609
# 4  0.263699  0.784612  1.031250
# 5  0.881478  0.012516  0.634277
# 6  0.533661  0.995825  0.455811
# 7  1.740885  3.056281  1.573242

# %%
frames=[df,q,df1]
result=pd.concat(frames,keys=['w','x','y','z'])
result
# Out:
#                               a         b         c         d         e    f  \
# w 2023-04-04 00:00:00 -0.197208 -0.003765 -1.741248 -0.770013 -0.003765 -5.0
#   2023-04-05 00:00:00 -1.516528 -0.332065 -0.073774 -0.713069 -0.332065 -5.0
#   2023-04-06 00:00:00 -0.677221 -0.064061 -1.199236 -0.017149 -0.064061 -5.0
#   2023-04-07 00:00:00 -1.445407 -1.354844 -1.601813 -0.582934 -1.354844 -5.0
#   2023-04-08 00:00:00 -1.664752 -0.387528 -0.547983 -2.373716 -0.387528 -5.0
#   2023-04-09 00:00:00 -0.479883 -0.756036 -2.004458 -0.365286 -0.756036 -5.0
#   2023-04-10 00:00:00 -1.133044 -0.325432 -0.649765 -0.367151 -0.325432 -5.0
# x 0                         NaN       NaN       NaN       NaN       NaN  NaN
#   1                         NaN       NaN       NaN       NaN       NaN  NaN
#   2                         NaN       NaN       NaN       NaN       NaN  NaN
#   3                         NaN       NaN       NaN       NaN       NaN  NaN
# ...

# %%
dff1=pd.DataFrame(np.random.randn(7,5),columns=list('abcde'))
dff1
# Out:
#           a         b         c         d         e
# 0 -1.532689  1.124471 -0.629686 -0.650668 -0.572884
# 1  1.345323  0.334008  1.408420  0.129684 -1.355104
# 2  0.939627 -0.756677 -0.428739  0.009766  1.347214
# 3 -0.484547  0.075857  0.052679  0.252940  0.321657
# 4  0.295669 -0.293065  1.034467  0.186131  1.231805
# 5 -2.170051  0.983590  0.547537  0.054716  0.119399
# 6  0.663802  0.666908  1.133235  1.432590 -1.267784

# %%
dff2=pd.DataFrame(np.random.randn(7,4),columns=list('abcd'))
dff2
# Out:
#           a         b         c         d
# 0 -0.811798 -1.152266  0.193060  0.421968
# 1  0.168332 -0.381576 -0.283262  1.586350
# 2 -0.109197 -0.615691 -0.885750 -2.502338
# 3  1.223106  0.422501 -1.187208  1.984610
# 4 -0.552217 -0.857123 -0.629889 -0.553496
# 5  2.070433 -0.838595 -0.817221 -0.830664
# 6 -0.118666  1.261523 -1.078608  1.427964

# %%
dff1['g']=np.array(5*len(dff1))

# %%
dff1
# Out:
#           a         b         c         d         e   g
# 0 -1.532689  1.124471 -0.629686 -0.650668 -0.572884  35
# 1  1.345323  0.334008  1.408420  0.129684 -1.355104  35
# 2  0.939627 -0.756677 -0.428739  0.009766  1.347214  35
# 3 -0.484547  0.075857  0.052679  0.252940  0.321657  35
# 4  0.295669 -0.293065  1.034467  0.186131  1.231805  35
# 5 -2.170051  0.983590  0.547537  0.054716  0.119399  35
# 6  0.663802  0.666908  1.133235  1.432590 -1.267784  35

# %%
dff2['g']=np.array(4*len(dff2))
dff2
# Out:
#           a         b         c         d   g
# 0 -0.811798 -1.152266  0.193060  0.421968  28
# 1  0.168332 -0.381576 -0.283262  1.586350  28
# 2 -0.109197 -0.615691 -0.885750 -2.502338  28
# 3  1.223106  0.422501 -1.187208  1.984610  28
# 4 -0.552217 -0.857123 -0.629889 -0.553496  28
# 5  2.070433 -0.838595 -0.817221 -0.830664  28
# 6 -0.118666  1.261523 -1.078608  1.427964  28

# %%
result2=pd.merge(dff1,dff2,how='left',on='g')
result2
# Out:
#         a_x       b_x       c_x       d_x         e   g  a_y  b_y  c_y  d_y
# 0 -1.532689  1.124471 -0.629686 -0.650668 -0.572884  35  NaN  NaN  NaN  NaN
# 1  1.345323  0.334008  1.408420  0.129684 -1.355104  35  NaN  NaN  NaN  NaN
# 2  0.939627 -0.756677 -0.428739  0.009766  1.347214  35  NaN  NaN  NaN  NaN
# 3 -0.484547  0.075857  0.052679  0.252940  0.321657  35  NaN  NaN  NaN  NaN
# 4  0.295669 -0.293065  1.034467  0.186131  1.231805  35  NaN  NaN  NaN  NaN
# 5 -2.170051  0.983590  0.547537  0.054716  0.119399  35  NaN  NaN  NaN  NaN
# 6  0.663802  0.666908  1.133235  1.432590 -1.267784  35  NaN  NaN  NaN  NaN

# %%
dff1.merge(dff2,how='right',on='g')
# Out:
#    a_x  b_x  c_x  d_x   e   g       a_y       b_y       c_y       d_y
# 0  NaN  NaN  NaN  NaN NaN  28 -0.811798 -1.152266  0.193060  0.421968
# 1  NaN  NaN  NaN  NaN NaN  28  0.168332 -0.381576 -0.283262  1.586350
# 2  NaN  NaN  NaN  NaN NaN  28 -0.109197 -0.615691 -0.885750 -2.502338
# 3  NaN  NaN  NaN  NaN NaN  28  1.223106  0.422501 -1.187208  1.984610
# 4  NaN  NaN  NaN  NaN NaN  28 -0.552217 -0.857123 -0.629889 -0.553496
# 5  NaN  NaN  NaN  NaN NaN  28  2.070433 -0.838595 -0.817221 -0.830664
# 6  NaN  NaN  NaN  NaN NaN  28 -0.118666  1.261523 -1.078608  1.427964

# %%
dff1.align(dff2,join='inner')
# Out:
# (          a         b         c         d   g
#  0 -1.532689  1.124471 -0.629686 -0.650668  35
#  1  1.345323  0.334008  1.408420  0.129684  35
#  2  0.939627 -0.756677 -0.428739  0.009766  35
#  3 -0.484547  0.075857  0.052679  0.252940  35
#  4  0.295669 -0.293065  1.034467  0.186131  35
#  5 -2.170051  0.983590  0.547537  0.054716  35
#  6  0.663802  0.666908  1.133235  1.432590  35,
#            a         b         c         d   g
#  0 -0.811798 -1.152266  0.193060  0.421968  28
#  1  0.168332 -0.381576 -0.283262  1.586350  28
#  2 -0.109197 -0.615691 -0.885750 -2.502338  28
#  3  1.223106  0.422501 -1.187208  1.984610  28
#  4 -0.552217 -0.857123 -0.629889 -0.553496  28
#  5  2.070433 -0.838595 -0.817221 -0.830664  28
#  6 -0.118666  1.261523 -1.078608  1.427964  28)

# %%
# Text data
s2 = pd.Series(["a_b_c", "c_d_e", np.nan, "f_g_h"], dtype="string")
s2
# Out:
# 0    a_b_c
# 1    c_d_e
# 2     <NA>
# 3    f_g_h
# dtype: string

# %%
import pandas as pd
import numpy as np
s3= pd.DataFrame({"A":["a_b_c", "c_d_e", np.nan, "f_g_h"]})
s3
# Out:
#        A
# 0  a_b_c
# 1  c_d_e
# 2    NaN
# 3  f_g_h

# %%
s3.columns
# Out:
# Index(['A'], dtype='object')

# %%
s3['B']=s3['A'].str.split('_').str.get(1)

# %%
s3
# Out:
#        A    B
# 0  a_b_c    b
# 1  c_d_e    d
# 2    NaN  NaN
# 3  f_g_h    g

# %%
s3.fillna(method='ffill')
# Out:
#        A  B
# 0  a_b_c  b
# 1  c_d_e  d
# 2  c_d_e  d
# 3  f_g_h  g

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
 d= {"a": list(range(4)), "b": list("ab.."), "c": ["a", "b", np.nan, "d"]}

df5 = pd.DataFrame(d)

 df5.replace(".", np.nan)
# Out:
#    a    b    c
# 0  0    a    a
# 1  1    b    b
# 2  2  NaN  NaN
# 3  3  NaN    d

# %%
df6=pd.DataFrame({"values":np.random.randint(0,100,20)})
labels=("{0}-{1}".format(i,i+9) for i in range(0,100,6))
df6["group"] = pd.cut(df6.values, range(0, 105, 10), right=False, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9724\3818983311.py in <module>
#       1 df6=pd.DataFrame({"values":np.random.randint(0,100,20)})
#       2 labels=("{0}-{1}".format(i,i+9) for i in range(0,100,6))
# ----> 3 df6["group"] = pd.cut(df6.values, range(0, 105, 10), right=False, labels=labels)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     239
#     240     original = x
# --> 241     x = _preprocess_for_cut(x)
#     242     x, dtype = _coerce_to_type(x)
#     243
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _preprocess_for_cut(x)
#     599         x = np.asarray(x)
#     600     if x.ndim != 1:
# --> 601         raise ValueError("Input array must be 1 dimensional")
#     602
# ...

# %%
for i in range(0,100,10):
    print(i,"-",i+9)
    i+=1
# Out:
# 0 - 9
# 10 - 19
# 20 - 29
# 30 - 39
# 40 - 49
# 50 - 59
# 60 - 69
# 70 - 79
# 80 - 89
# 90 - 99

# %%
np((4,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9724\626768314.py in <module>
# ----> 1 np((4,2))
#
# TypeError: 'module' object is not callable

# %%
str1
# Out:
# 'amarenra kumar kushwaha'

# %%
str1='amarenra kumar kushwaha'
dct={}
dct1={}
vowels='AEIOUaeiou'
for s in str1:
    if s in vowels:
        if s in dct:
            dct[s]+=1
        else:
            dct[s]=1
    else:
        if s in dct1:
            dct1[s]+=1
        else:
            dct1[s]=1
print(dct)
print(dct1)
# Out:
# {'a': 6, 'e': 1, 'u': 2}
# {'m': 2, 'r': 3, 'n': 1, ' ': 2, 'k': 2, 's': 1, 'h': 2, 'w': 1}

# %%
max(dct1,key=dct1.get)
# Out:
# 'r'

# %%
data=pd.date_range("11/25/2023",periods=7)
d1=pd.DataFrame(np.random.randn(7,3),index=data,columns=['id','name','products'])
d1
# Out:
#                   id      name  products
# 2023-11-25 -1.999624 -1.779493  0.413055
# 2023-11-26 -1.039922  2.111657  2.673677
# 2023-11-27 -0.322038 -0.071258  0.798912
# 2023-11-28 -0.299670 -0.994916  0.857342
# 2023-11-29  0.712561  0.514762 -0.897534
# 2023-11-30 -0.081477  0.381475  0.911260
# 2023-12-01  0.978930 -0.833662 -1.070710

# %%
pd.Series(ids)
# Out:
# 2023-11-25   -1.999624
# 2023-11-26   -1.039922
# Freq: D, Name: id, dtype: float64

# %%
ids=d1['produc'][:2]
ids
# Out:
# 2023-11-25   -1.999624
# 2023-11-26   -1.039922
# Freq: D, Name: id, dtype: float64

# %%
d2=pd.DataFrame({'date':data,'order_stats':pd.Series(ids)},columns=['date','order_stats'])
d2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9724\1072957488.py in <module>
# ----> 1 d2=pd.DataFrame({'date':data,'order_stats':pd.Series(ids)},columns=['date','order_stats'])
#       2 d2
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     448             # GH10856
# ...

# %%
e=d2['id'][:2]
e
# Out:
# 0    0.458534
# 1    0.973841
# Name: id, dtype: float32

# %%
pd.merge(d1,d2,on='id')
# Out:
# Empty DataFrame
# Columns: [id, name, products, date, order_stats]
# Index: []

# %%
pd.DataFrame({'A':pd.Series(e),
             "B":pd.Series(np.random.randn(7))})
# Out:
#           A         B
# 0  0.458534 -0.676811
# 1  0.973841 -0.913822
# 2       NaN -0.103486
# 3       NaN -1.072960
# 4       NaN -0.037923
# 5       NaN -0.718027
# 6       NaN  1.611654
